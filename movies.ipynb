# %%
import  pandas as pd
df=pd.read_csv(r"D:\DataSets\TMDB_movie_dataset_v11.csv")

# %%
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %% [markdown]
# unfiltered data

# %%
# how many rows & columns
df.shape
# Out:
# (1283621, 24)

# %% [markdown]
# conclusion: raw data has 1283621 rows and  24 columns

# %%
# check missing data.
df.isnull().sum().sort_values(ascending=False)
# homepage  has the maximum null values
# Out:
# homepage                1149778
# tagline                 1104283
# backdrop_path            954141
# keywords                 953335
# production_companies     721735
# imdb_id                  646184
# production_countries     599219
# spoken_languages         575557
# genres                   543008
# poster_path              432436
# overview                 281714
# release_date             251489
# title                        15
# original_title               15
# id                            0
# vote_average                  0
# runtime                       0
# revenue                       0
# status                        0
# vote_count                    0
# original_language             0
# budget                        0
# adult                         0
# popularity                    0
# dtype: int64

# %% [markdown]
# In raw data, homepage has the maximum null values followed by tagline

# %%
# summary of numeric columns.
pd.set_option("display.float_format","{:,.0f}".format) ## to get non scientific format
df.describe()
# Out:
#              id  vote_average  vote_count       revenue   runtime      budget  \
# count 1,283,621     1,283,621   1,283,621     1,283,621 1,283,621   1,283,621
# mean    823,792             2          17       650,521        46     251,640
# std     438,688             3         300    18,705,956        61   5,162,115
# min           2             0           0           -12       -28           0
# 25%     454,735             0           0             0         0           0
# 50%     834,823             0           0             0        18           0
# 75%   1,213,815             4           1             0        87           0
# max   1,542,225            10      34,495 4,999,999,999    14,400 999,999,999
#
#        popularity
# count   1,283,621
# mean            1
# std             7
# min             0
# 25%             1
# 50%             1
# 75%             1
# max         2,994

# %% [markdown]
# conclusion: intersting observation is noted that minimum runtime is -28 is would be considered for removal

# %%
# datatypes, missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1283621 entries, 0 to 1283620
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1283621 non-null  int64
#  1   title                 1283606 non-null  object
#  2   vote_average          1283621 non-null  float64
#  3   vote_count            1283621 non-null  int64
#  4   status                1283621 non-null  object
#  5   release_date          1032132 non-null  object
#  6   revenue               1283621 non-null  int64
#  7   runtime               1283621 non-null  int64
#  8   adult                 1283621 non-null  bool
#  9   backdrop_path         329480 non-null   object
#  10  budget                1283621 non-null  int64
#  11  homepage              133843 non-null   object
#  12  imdb_id               637437 non-null   object
#  13  original_language     1283621 non-null  object
# ...
